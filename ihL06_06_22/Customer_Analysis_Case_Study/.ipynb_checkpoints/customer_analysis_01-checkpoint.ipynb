# %% [markdown]
# # Customer analysis

# %%
import numpy as np
import pandas as pd

pd.options.display.max_rows = 100

# %% [markdown]
#  #### Read the data

# %%
file1 = pd.read_csv('Data/file1.csv')
file2 = pd.read_csv('Data/file2.csv')
file3 = pd.read_csv('Data/file3.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                      88                    1/0/00          633.600000
# 1                     114                    1/0/00          547.200000
# 2                     112                    1/0/00          537.600000
# 3                     214                    1/1/00         1027.200000
# 4                      94                    1/0/00          451.200000
# ..                    ...                       ...                 ...
# 991                    70                    1/0/00          185.667213
# 992                    68                    1/0/00          140.747286
# 993                    70                    1/0/00          471.050488
# 994                    96                    1/0/00           28.460568
# 995                   111                    1/0/00          700.349052
#
#         Policy Type  Vehicle Class
# 0     Personal Auto  Four-Door Car
# 1      Special Auto            SUV
# 2     Personal Auto   Two-Door Car
# 3     Personal Auto     Luxury Car
# 4    Corporate Auto   Two-Door Car
# ..              ...            ...
# 991   Personal Auto  Four-Door Car
# 992  Corporate Auto  Four-Door Car
# 993  Corporate Auto   Two-Door Car
# 994   Personal Auto   Two-Door Car
# 995   Personal Auto            SUV
#
# [996 rows x 11 columns]

# %%
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          Policy Type  Total Claim Amount  Vehicle Class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %% [markdown]
# #### First clean the data on a file to file basis:
#  - file 1 has some NaNs for complaints and the rest are double / separated
#  - file 2 has / separated complaints
#  - file 3 has integers complains

# %%
file1['Number of Open Complaints']= file1['Number of Open Complaints'].fillna('0/0/00') # fill the nans in file1

# %%
def get_between_slash(data_col):
    z = [x[1] for x in data_col.str.split('/') if type(x) != float]
    return z

# %%
file1['Number of Open Complaints']=get_between_slash(file1['Number of Open Complaints'])
file2['Number of Open Complaints']=get_between_slash(file2['Number of Open Complaints'])

# %%
#file1['Number of Open Complaints']=[x[1] for x in file1['Number of Open Complaints'].str.split('/')\
                                   # if type(x) != float] # split on the / and take the middle file

# %%
#file2['Number of Open Complaints']=[x[1] for x in file2['Number of Open Complaints'].str.split('/')\ 
                                  # if type(x) != float]

# %% [markdown]
# #### Prepare the data for concat

# %%
file3.rename(columns = {'State':'ST'}, inplace = True) # rename file3's state col

# %%
def lower_case_column_names(df):
    ''' make columns lower case '''
    df.columns=[i.lower() for i in df.columns]
    return df

# %%
lower_case_column_names(file1)
lower_case_column_names(file2)
lower_case_column_names(file3)
# Out:
#      customer          st  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# 0         M       0                   104                          0
# 1         M       0                    66                          0
# 2         F   25820                    82                          0
# 3         F       0                   121                          0
# 4         M   30366                   101                          2
# ...     ...     ...                   ...                        ...
# 7065      M   71941                    73                          0
# 7066      F   21604                    79                          0
# 7067      M       0                    85                          3
# 7068      M   21941                    96                          0
# 7069      M       0                    77                          0
#
#          policy type  total claim amount  vehicle class
# 0      Personal Auto          499.200000   Two-Door Car
# 1      Personal Auto            3.468912   Two-Door Car
# 2      Personal Auto          393.600000  Four-Door Car
# 3      Personal Auto          699.615192            SUV
# 4      Personal Auto          484.800000            SUV
# ...              ...                 ...            ...
# 7065   Personal Auto          198.234764  Four-Door Car
# 7066  Corporate Auto          379.200000  Four-Door Car
# 7067  Corporate Auto          790.784983  Four-Door Car
# 7068   Personal Auto          691.200000  Four-Door Car
# 7069  Corporate Auto          369.600000   Two-Door Car
#
# [7070 rows x 11 columns]

# %%
c_df = pd.concat([file1,file2,file3]) # concat the data.

# %%
c_df.income = c_df.income.fillna(c_df.income.median()) # fill 
c_df.income = c_df.income.apply(round)

# %%
c_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   st                         9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer lifetime value    9130 non-null   object
#  5   income                     12074 non-null  int64
#  6   monthly premium auto       9137 non-null   float64
#  7   number of open complaints  12074 non-null  object
#  8   policy type                9137 non-null   object
#  9   vehicle class              9137 non-null   object
#  10  total claim amount         9137 non-null   float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 1.1+ MB

# %%
c_df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value  income  monthly premium auto  \
# 0                        NaN       0                1000.0
# 1                 697953.59%       0                  94.0
# 2                1288743.17%   48767                 108.0
# 3                 764586.18%       0                 106.0
# 4                 536307.65%   36357                  68.0
# ...                      ...     ...                   ...
# 7065             23405.98798   71941                  73.0
# 7066             3096.511217   21604                  79.0
# 7067             8163.890428       0                  85.0
# 7068             7524.442436   21941                  96.0
# 7069             2611.836866       0                  77.0
#
#      number of open complaints     policy type  vehicle class  \
# 0                            0   Personal Auto  Four-Door Car
# 1                            0   Personal Auto  Four-Door Car
# 2                            0   Personal Auto   Two-Door Car
# 3                            0  Corporate Auto            SUV
# 4                            0   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 7065                         0   Personal Auto  Four-Door Car
# 7066                         0  Corporate Auto  Four-Door Car
# 7067                         3  Corporate Auto  Four-Door Car
# 7068                         0   Personal Auto  Four-Door Car
# 7069                         0  Corporate Auto   Two-Door Car
#
#       total claim amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 7065          198.234764
# 7066          379.200000
# 7067          790.784983
# 7068          691.200000
# 7069          369.600000
#
# [12074 rows x 11 columns]

# %%
c_df.describe()
# Out:
#              income  monthly premium auto  total claim amount
# count  12074.000000           9137.000000         9137.000000
# mean   36956.812904            110.391266          430.527140
# std    26453.868168            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%    21585.250000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    53301.750000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %% [markdown]
# ### Cleaning customer lifetime value
# - Remove %s
# - change NaNs to median value
# - round the numbers

# %%
c_df['customer lifetime value']
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: customer lifetime value, Length: 12074, dtype: object

# %%
#c_df['customer lifetime value']=c_df['customer lifetime value'].str.strip("%").astype(float) # NaNs are floats

# %% [markdown]
# #### Remove %, replace NaNs in customer lifetime by the median customer lifetime, then round.

# %%
c_df['customer lifetime value'] = c_df['customer lifetime value'].str.strip("%").astype(float) # NaNs are float
c_df['customer lifetime value'] = c_df['customer lifetime value'].fillna(c_df['customer lifetime value'].median())
c_df['customer lifetime value'] = c_df['customer lifetime value'].astype(int) # round to int

# %% [markdown]
# ### Replacements: state -> state abreviations, fix gender typos and

# %%
us_state_to_abbrev = {
    "Alabama": "AL",
    "Alaska": "AK",
    "Arizona": "AZ",
    "Arkansas": "AR",
    "California": "CA",
    "Colorado": "CO",
    "Connecticut": "CT",
    "Delaware": "DE",
    "Florida": "FL",
    "Georgia": "GA",
    "Hawaii": "HI",
    "Idaho": "ID",
    "Illinois": "IL",
    "Indiana": "IN",
    "Iowa": "IA",
    "Kansas": "KS",
    "Kentucky": "KY",
    "Louisiana": "LA",
    "Maine": "ME",
    "Maryland": "MD",
    "Massachusetts": "MA",
    "Michigan": "MI",
    "Minnesota": "MN",
    "Mississippi": "MS",
    "Missouri": "MO",
    "Montana": "MT",
    "Nebraska": "NE",
    "Nevada": "NV",
    "New Hampshire": "NH",
    "New Jersey": "NJ",
    "New Mexico": "NM",
    "New York": "NY",
    "North Carolina": "NC",
    "North Dakota": "ND",
    "Ohio": "OH",
    "Oklahoma": "OK",
    "Oregon": "OR",
    "Pennsylvania": "PA",
    "Rhode Island": "RI",
    "South Carolina": "SC",
    "South Dakota": "SD",
    "Tennessee": "TN",
    "Texas": "TX",
    "Utah": "UT",
    "Vermont": "VT",
    "Virginia": "VA",
    "Washington": "WA",
    "West Virginia": "WV",
    "Wisconsin": "WI",
    "Wyoming": "WY",
    "District of Columbia": "DC",
    "American Samoa": "AS",
    "Guam": "GU",
    "Northern Mariana Islands": "MP",
    "Puerto Rico": "PR",
    "United States Minor Outlying Islands": "UM",
    "U.S. Virgin Islands": "VI",
}

# %%
c_df['st'] = c_df['st'].replace(us_state_to_abbrev) # replace states by abbrev
c_df['st'] = c_df['st'].replace({'Cali': 'CA'}) # additional replacement

# %%
c_df.head(3)
# Out:
#   customer  st gender education  customer lifetime value  income  \
# 0  RB50392  WA    NaN    Master                   572027       0
# 1  QZ44356  AZ      F  Bachelor                   697953       0
# 2  AI49188  NV      F  Bachelor                  1288743   48767
#
#    monthly premium auto number of open complaints    policy type  \
# 0                1000.0                         0  Personal Auto
# 1                  94.0                         0  Personal Auto
# 2                 108.0                         0  Personal Auto
#
#    vehicle class  total claim amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247

# %%
gend_replace = {'Male': "M", "Female" :  "F", "Femal" : "F" }
c_df['gender'] = c_df['gender'].replace(gend_replace) # additional replacement

# %%
c_df.gender.str.contains('Femal').value_counts()
# Out:
# False    9015
# Name: gender, dtype: int64

# %%
c_df = c_df.drop(labels=['customer'], axis=1) # drop customer label

# %%
c_df = c_df.drop_duplicates() # remove duplicates

# %% [markdown]
# ### Replace zero income with mean

# %%
c_df.income = c_df.income.replace(0, c_df.income.mean()).round(0)
c_df.income.head()

# %%
def c_lower(col):
    return col.str.lower()

# %%
c_df.education = lower(c_df.education)

# %%
print(c_df.education)
